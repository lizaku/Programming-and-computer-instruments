# %% [markdown]
# # Автоматическое извлечение коллокаций
# ## С помощью nltk
# Итак, на прошлой лекции вы узнали что такое коллокации и как какие существуют меры оценки коллокационной связи.
# Теперь мы попытаемся научиться со всем этим работать при помощи nltk, а точнее его подмодуля nltk.collocations

# %%
import nltk
from nltk.collocations import *
bigram_measures = nltk.collocations.BigramAssocMeasures()
trigram_measures = nltk.collocations.TrigramAssocMeasures()

# %% [markdown]
# _nltk_ - довольно высокоуровневый модуль, поэтому мы можем дать ему на вход просто текст, поделенный на слова, не выделяя биграммы самим, и он за нас сам разделит наш массив слов на биграммы.
#
# Мы возьмем небольшой корпус, составленный из текстов интернет-новостей. В нем 171 тыс. слов - не очень много, но для экспериментов хватит. Для начала поделим текст на слова просто по пробелам.

# %%
words = open('news.txt').read().split()
words
# Out:
# ['Губернаторы',
#  'отвыкли',
#  'от',
#  'публичной',
#  'политики,',
#  'и',
#  'их',
#  'придется',
#  'учить',
#  'общаться',
#  'с',
#  'избирателями',
#  '—',
#  'об',
#  'этом',
#  'говорили',
#  'на',
#  'встрече',
#  'в',
#  'Кремле',
#  'с',
#  'политологами',
#  'Вячеслав',
#  'Володин',
#  'и',
#  'другие',
#  'кураторы',
#  'внутренней',
#  'политики.',
#  'Но',
#  'недовольство',
#  'руководства',
#  'страны',
#  'вызывают',
#  'только',
#  'главы',
#  'тех',
#  'регионов,',
#  'где',
#  'нет',
#  'реальной',
#  'угрозы',
#  'власти,',
#  'объясняет',
#  'участник',
#  'встречи.',
#  'С',
#  'реальными',
#  'оппонентами',
#  'местных',
#  'властей',
#  'Кремль',
#  'сам',
#  'помогает',
#  'бороться.',
#  'На',
#  'встречу',
#  'с',
#  'первым',
#  'замглавы',
#  'администрации',
#  'президента',
#  'Вячеславом',
#  'Володиным',
#  'пригласили',
#  'около',
#  '30',
#  'политологов,',
#  'в',
#  'первую',
#  'очередь',
#  'тех,',
#  'кто',
#  'назначен',
#  'Кремлем',
#  'наблюдать',
#  'за',
#  'ходом',
#  'избирательных',
#  'кампаний',
#  'на',
#  'местах,',
#  'рассказали',
#  'РБК',
#  'несколько',
#  'участников',
#  'встречи.',
#  'По',
#  'словам',
#  'собеседников,',
#  'от',
#  'администрации',
#  'президента',
#  'помимо',
#  'Володина',
#  'были',
#  'еще',
#  'руководитель',
#  'внутренней',
#  'политики',
#  'Олег',
#  'Морозов',
#  'и',
#  'его',
#  'заместитель',
#  'Татьяна',
#  'Воронова.',
#  'Поводом',
#  'для',
#  'встречи',
#  'стала',
#  'подготовка',
#  'к',
#  'региональным',
#  'выборам,',
#  'которые',
#  'пройдут',
#  '14',
#  'сентября.',
#  'Избирательная',
#  'кампания',
#  'показала,',
#  'что',
#  'за',
#  'годы',
#  'отсутствия',
#  'прямых',
#  'выборов',
#  'в',
#  'регионах',
#  'ухудшилось',
#  'понимание',
#  'внутриполитической',
#  'работы,',
#  'губернаторы',
#  'отвыкли',
#  'от',
#  'публичной',
#  'политики',
#  '—',
#  'эта',
#  'проблема',
#  'обсуждалась',
#  'на',
#  'встрече,',
#  'рассказал',
#  'РБК',
#  'руководитель',
#  'близкого',
#  'к',
#  'Кремлю',
#  'Фонда',
#  'ИСЭПИ',
#  'Дмитрий',
#  'Бадовский.',
#  'Участники',
#  'говорили,',
#  'что',
#  'в',
#  'некоторых',
#  'регионах',
#  'в',
#  'новостях',
#  'вообще',
#  'не',
#  'упоминают',
#  'выборы',
#  'и',
#  'люди',
#  'о',
#  'них',
#  'даже',
#  'не',
#  'знают,',
#  'говорит',
#  'директор',
#  'фонда',
#  '«Петербургская',
#  'политика»',
#  'Михаил',
#  'Виноградов.',
#  'По',
#  'его',
#  'словам,',
#  'губернаторы',
#  'считают,',
#  'что',
#  'так',
#  'они',
#  'обеспечат',
#  'участие',
#  'в',
#  'выборах',
#  'только',
#  'лояльных',
#  'избирателей.',
#  'В',
#  'вину',
#  'региональным',
#  'властям',
#  'ставили',
#  'и',
#  'организацию',
#  'досрочного',
#  'голосования.',
#  'Например,',
#  'в',
#  'Санкт-Петербурге',
#  '«Справедливая',
#  'Россия»',
#  'уже',
#  'заявила,',
#  'что',
#  'городские',
#  'власти',
#  'заставляют',
#  'людей',
#  'в',
#  'массовом',
#  'порядке',
#  'досрочно',
#  'участвовать',
#  'в',
#  'выборах.',
#  'Некоторые',
#  'губернаторы',
#  'ошибочно',
#  'считают,',
#  'что',
#  'легитимность',
#  'выборов',
#  'определяется',
#  'цифрами,',
#  'например',
#  'высокой',
#  'явкой,',
#  'но',
#  'в',
#  'администрации',
#  'президента',
#  'дали',
#  'понять,',
#  'что',
#  'легитимность',
#  'определяется',
#  'тем,',
#  'насколько',
#  'общество',
#  'и',
#  'местные',
#  'элиты',
#  'признают',
#  'результат,',
#  'говорит',
#  'директор',
#  'ИСЭПИ',
#  'по',
#  'исследованиям',
#  'Александр',
#  'Пожалов.',
#  'По',
#  'словам',
#  'другого',
#  'участника',
#  'встречи,',
#  'в',
#  'Кремле',
#  'обещают',
#  'наказать',
#  'виновных',
#  'в',
#  'нарушениях',
#  'на',
#  'досрочном',
#  'голосовании.',
#  'Объяснять',
#  'губернаторам,',
#  'что',
#  'надо',
#  'работать',
#  'другими',
#  'методами,',
#  'будут',
#  'на',
#  'учебе,',
#  'которую',
#  'администрация',
#  'президента',
#  'в',
#  'этом',
#  'году',
#  'вновь',
#  'проведет',
#  'для',
#  'глав',
#  'регионов',
#  'и',
#  'их',
#  'заместителей',
#  'по',
#  'внутренней',
#  'политике,',
#  'говорит',
#  'Бадовский.',
#  'По',
#  'его',
#  'словам,',
#  'чиновникам',
#  'нужно',
#  'рассказывать,',
#  'как',
#  'общаться',
#  'с',
#  'людьми,',
#  'что',
#  'такое',
#  'современный',
#  'политический',
#  'язык,',
#  'что',
#  'такое',
#  'коммуникации',
#  'и',
#  'устойчивая',
#  'система',
#  'обратной',
#  'связи.',
#  '«Губернаторам',
#  'уже',
#  'сейчас',
#  'объясняют,',
#  'что',
#  'надо',
#  'жить',
#  'и',
#  'работать',
#  'в',
#  'иной',
#  'реальности',
#  '—',
#  'реальности',
#  'публичной',
#  'и',
#  'конкурентной',
#  'политики»,',
#  '—',
#  'говорит',
#  'руководитель',
#  'ИСЭПИ.',
#  'В',
#  'Кремле',
#  'критикуют',
#  'тех',
#  'губернаторов,',
#  'которые',
#  'борются',
#  'с',
#  'кандидатами,',
#  'не',
#  'представляющими',
#  'для',
#  'них',
#  'серьезной',
#  'угрозы,',
#  'объясняет',
#  'участвовавший',
#  'во',
#  'встрече',
#  'президент',
#  'Центра',
#  'политических',
#  'технологий',
#  'Игорь',
#  'Бунин.',
#  'Поэтому',
#  'особой',
#  'критике',
#  'ранее',
#  'уже',
#  'подвергались',
#  'нижегородский',
#  'руководитель',
#  'Валерий',
#  'Шанцев',
#  'и',
#  'липецкий',
#  'губернатор',
#  'Олег',
#  'Королев',
#  '—',
#  'их',
#  'основные',
#  'оппоненты',
#  'не',
#  'были',
#  'допущены',
#  'до',
#  'выборов',
#  'благодаря',
#  'так',
#  'называемому',
#  'муниципальному',
#  'фильтру,',
#  'хотя,',
#  'по',
#  'словам',
#  'источника',
#  'РБК',
#  'в',
#  'Кремле,',
#  'те',
#  'не',
#  'имели',
#  'никаких',
#  'шансов',
#  'на',
#  'победу.',
#  'Если',
#  'же',
#  'угроза',
#  'от',
#  'оппонентов',
#  'реальна,',
#  'то',
#  'администрация',
#  'президента',
#  'сама',
#  'помогает',
#  'губернаторам',
#  'решить',
#  'проблемы,',
#  'отмечает',
#  'Бунин.',
#  '«Правда,',
#  'считается,',
#  'что',
#  'лучше',
#  'помогать',
#  'советом',
#  'или',
#  'приездом',
#  'президента',
#  '(в',
#  'начале',
#  'сентября',
#  'Путин',
#  'ездил',
#  'в',
#  'проблемные',
#  'Республику',
#  'Алтай',
#  'и',
#  'Якутию).',
#  'Но',
#  'в',
#  'особых',
#  'случаях',
#  'и',
#  'для',
#  'особо',
#  'святых',
#  'кандидатов',
#  'в',
#  'губернаторы,',
#  'таких',
#  'как',
#  'губернатор',
#  'Санкт-Петербурга',
#  '[Георгий',
#  'Полтавченко],',
#  'возможна',
#  'и',
#  'помощь',
#  'административным',
#  'ресурсом»,',
#  '—',
#  'отмечает',
#  'эксперт.',
#  'Поэтому,',
#  'как',
#  'объясняют',
#  'участники',
#  'встречи,',
#  'Володин',
#  'высказался',
#  'за',
#  'сохранение',
#  'муниципального',
#  'фильтра.',
#  'Правда,',
#  'официальная',
#  'аргументация',
#  '—',
#  'фильтр',
#  'стимулирует',
#  'партии',
#  'участвовать',
#  'в',
#  'выборах',
#  'всех',
#  'уровней,',
#  'а',
#  'не',
#  'только',
#  'федеральных',
#  'или',
#  'региональных,',
#  'добавляет',
#  'Бунин.',
#  'На',
#  'пост',
#  'председателя',
#  'совета',
#  'директоров',
#  '«Российских',
#  'железных',
#  'дорог»',
#  'переизбран',
#  'управляющий',
#  'партнер',
#  'инвестиционной',
#  'компании',
#  'Altera',
#  'Capital',
#  'Кирилл',
#  'Андросов.',
#  'Решение',
#  'о',
#  'продлении',
#  'полномочий',
#  'Андросова,',
#  'возглавляющего',
#  'совет',
#  'директоров',
#  'РЖД',
#  'с',
#  'сентября',
#  '2011',
#  'года,',
#  'было',
#  'принято',
#  'на',
#  'вчерашнем',
#  'заседании',
#  'совета,',
#  'сообщила',
#  'монополия.',
#  'В',
#  'июле',
#  'в',
#  'совет',
#  'директоров',
#  'РЖД',
#  'вошли',
#  'несколько',
#  'новых',
#  'человек,',
#  'в',
#  'том',
#  'числе',
#  'Сергей',
#  'Степашин,',
#  'председатель',
#  'наблюдательного',
#  'совета',
#  'Фонда',
#  'содействия',
#  'реформированию',
#  'ЖКХ.',
#  'Близкие',
#  'к',
#  'руководству',
#  'РЖД',
#  'источники',
#  'заявляли',
#  'тогда',
#  'РБК,',
#  'что',
#  'Степашин',
#  'может',
#  'стать',
#  'и',
#  'новым',
#  'главой',
#  'совета',
#  'директоров.',
#  'Андросов',
#  'же',
#  '—',
#  'противовес',
#  'президенту',
#  'РЖД',
#  'Владимиру',
#  'Якунину.',
#  'Андросов',
#  'известен',
#  'открытой',
#  'критикой',
#  'ряда',
#  'идей',
#  'Якунина.',
#  'В',
#  'частности,',
#  'в',
#  'начале',
#  'июля,',
#  'голосуя',
#  'на',
#  'заседании',
#  'совета',
#  'директоров,',
#  'он,',
#  'как',
#  'сообщили',
#  'РБК',
#  'два',
#  'источника,',
#  'близких',
#  'к',
#  'совету,',
#  'заблокировал',
#  'создание',
#  'российско-белорусско-казахской',
#  'Объединенной',
#  'транспортно-логистической',
#  'компании',
#  '(ОТЛК),',
#  'которого',
#  'добивался',
#  'Якунин.',
#  'Якунин',
#  'работал',
#  'без',
#  'переутверждения',
#  'больше',
#  'двух',
#  'месяцев',
#  '—',
#  'срок',
#  'его',
#  'полномочий',
#  'истек',
#  '10',
#  'июня,',
#  'а',
#  'новое',
#  'распоряжение',
#  'о',
#  'его',
#  'переназначении',
#  'премьер-министр',
#  'Дмитрий',
#  'Медведев',
#  'подписал',
#  'только',
#  '25',
#  'августа.',
#  '«В',
#  'нынешних',
#  'довольно',
#  'сложных',
#  'условиях',
#  'нужно',
#  'будет',
#  'продолжить',
#  'работу',
#  'по',
#  'развитию',
#  'сети',
#  '«Российских',
#  'железных',
#  'дорог»,',
#  'по',
#  'инвестированию',
#  'средств',
#  'в',
#  'различные',
#  'объекты',
#  'открытого',
#  'акционерного',
#  'общества',
#  '«Российские',
#  'железные',
#  'дороги».',
#  'Естественно,',
#  'заботиться',
#  'о',
#  'персонале,',
#  'потому',
#  'что',
#  'все-таки',
#  'это',
#  'самое',
#  'главное,',
#  'что',
#  'есть',
#  'у',
#  'общества,',
#  'самое',
#  'главное',
#  'богатство,',
#  'и,',
#  'наверное,',
#  'искать',
#  'дополнительные',
#  'источники',
#  'финансирования.',
#  'Желаю',
#  'вам',
#  'успехов»,',
#  '—',
#  'заявил',
#  'премьер-министр,',
#  'встречаясь',
#  'с',
#  'Якуниным',
#  'в',
#  'день',
#  'его',
#  'назначения.',
#  'Президент',
#  'РЖД',
#  'пообещал,',
#  'что',
#  'постарается',
#  'оправдать',
#  'все',
#  'ожидания.',
#  'В',
#  'июне',
#  'высокопоставленный',
#  'чиновник',
#  'правительства',
#  'говорил',
#  'РБК,',
#  'что',
#  'хотя',
#  'глава',
#  'РЖД',
#  'достиг',
#  'пенсионного',
#  'возраста',
#  '(ему',
#  '65',
#  'лет),',
#  'президент',
#  'РФ',
#  'Владимир',
#  'Путин',
#  '«из',
#  'принципа»',
#  'не',
#  'станет',
#  'его',
#  'менять,',
#  'пока',
#  'Якунин',
#  'остается',
#  'под',
#  'санкциями',
#  'Запада.',
#  'В',
#  'марте',
#  'Министерство',
#  'финансов',
#  'США',
#  'внесло',
#  'Якунина',
#  'в',
#  'список',
#  'россиян,',
#  'которым',
#  'запрещен',
#  'въезд',
#  'в',
#  'страну,',
#  'а',
#  'их',
#  'активы',
#  'на',
#  'ее',
#  'территории',
#  'должны',
#  'быть',
#  'заморожены.',
#  'Среди',
#  '20',
#  'человек,',
#  'оказавшихся',
#  'под',
#  'санкциями,',
#  'только',
#  'четверо',
#  'не',
#  'занимают',
#  'государственных',
#  'постов,',
#  'зато,',
#  'по',
#  'данным',
#  'Минфина',
#  'США,',
#  'составляют',
#  'близкий',
#  'круг',
#  'президента',
#  'России.',
#  'Власти',
#  'Украины',
#  'так',
#  'и',
#  'не',
#  'определили',
#  'границы',
#  'территории,',
#  'которую',
#  'Верховная',
#  'рада',
#  'наделила',
#  'автономией,',
#  'признало',
#  'командование',
#  'антитеррористической',
#  'операции.',
#  'В',
#  'настоящее',
#  'время',
#  'повстанцы',
#  'контролируют',
#  'около',
#  'трети',
#  'общей',
#  'площади',
#  'Луганской',
#  'и',
#  'Донецкой',
#  'областей,',
#  'но',
#  'их',
#  'границы',
#  'постоянно',
#  'пересматриваются',
#  '–',
#  'несмотря',
#  'на',
#  'объявленное',
#  '5',
#  'сентября',
#  'прекращение',
#  'огня,',
#  'противостояние',
#  'продолжается',
#  'в',
#  'ряде',
#  'районов.',
#  '«В',
#  'законе',
#  'говорится',
#  'о',
#  'территориях,',
#  'временно',
#  'находящихся',
#  'под',
#  'контролем',
#  'ополченцев,',
#  'однако',
#  'речи',
#  'об',
#  'определении',
#  'границ',
#  'этих',
#  'территорий',
#  'пока',
#  'не',
#  'идет»,',
#  '–',
#  'заявил',
#  'в',
#  'четверг',
#  'на',
#  'брифинге',
#  'официальный',
#  'представитель',
#  'Совета',
#  'национальной',
#  'безопасности',
#  'и',
#  'обороны',
#  'Андрей',
#  'Лысенко.',
#  'По',
#  'его',
#  'словам,',
#  'пока',
#  'действует',
#  'режим',
#  'прекращения',
#  'огня,',
#  'украинская',
#  'армия',
#  'рассчитывает',
#  '«укрепить',
#  'силы»,',
#  'но',
#  '«все,',
#  'что',
#  'произойдет',
#  'в',
#  'дальнейшем,',
#  '–',
#  'неизвестно».',
#  'Принятый',
#  'Верховной',
#  'радой',
#  'во',
#  'вторник',
#  'закон',
#  'оговаривает,',
#  'что',
#  'определять',
#  'границы',
#  'территорий,',
#  'которым',
#  'придан',
#  'особый',
#  'статус,',
#  'должен',
#  'руководитель',
#  'Антитеррористического',
#  'центра',
#  'при',
#  'Службе',
#  'безопасности',
#  'Украины.',
#  'Закон,',
#  'который',
#  'собирается',
#  'оспаривать',
#  'в',
#  'Конституционном',
#  'суде',
#  'фракция',
#  '«Батькивщина»',
#  'Юлии',
#  'Тимошенко,',
#  'был',
#  'поправлен.',
#  'Как',
#  'утверждает',
#  'депутат',
#  'и',
#  'бывший',
#  'министр',
#  'обороны',
#  'Анатолий',
#  'Гриценко,',
#  'в',
#  'том',
#  'документе,',
#  'который',
#  'его',
#  'коллеги',
#  'получили',
#  'на',
#  'руки',
#  'во',
#  'вторник',
#  'перед',
#  'голосованием,',
#  'указывается,',
#  'что',
#  'границы',
#  'районов',
#  'с',
#  'особым',
#  'статусом',
#  'определяет',
#  'Верхов\xadная',
#  'рада.',
#  'Сами',
#  'ополченцы',
#  'считают',
#  'территорией',
#  '«народных',
#  'республик»',
#  'всю',
#  'территорию',
#  'Донбасса.',
#  '«Мы',
#  'со',
#  'своей',
#  'стороны',
#  'ведем',
#  'речь',
#  'о',
#  'территориях',
#  'бывших',
#  'Донецкой',
#  'и',
#  'Луганской',
#  ...]

# %% [markdown]
# Можно однако вспомнить, что мы тут компьютерные лингвисты, и осуществить простейшую предобработку текста - очистку от знаков препинания и лемматизацию.
#
# Для лемматизации в данном случае используем pymorphy.

# %%
import pymorphy2
morph = pymorphy2.MorphAnalyzer()
punct = '.,!?():;'
words = [word.strip(punct) for word in open('news.txt').read().split()]
words_tagged = [morph.parse(word)[0].normal_form for word in words]
words_tagged
# Out:
# ['губернатор',
#  'отвыкнуть',
#  'от',
#  'публичный',
#  'политика',
#  'и',
#  'они',
#  'прийтись',
#  'учить',
#  'общаться',
#  'с',
#  'избиратель',
#  '—',
#  'о',
#  'это',
#  'говорить',
#  'на',
#  'встреча',
#  'в',
#  'кремль',
#  'с',
#  'политолог',
#  'вячеслав',
#  'володин',
#  'и',
#  'другой',
#  'куратор',
#  'внутренний',
#  'политика',
#  'но',
#  'недовольство',
#  'руководство',
#  'страна',
#  'вызывать',
#  'только',
#  'глава',
#  'тот',
#  'регион',
#  'где',
#  'нет',
#  'реальный',
#  'угроза',
#  'власть',
#  'объяснять',
#  'участник',
#  'встреча',
#  'с',
#  'реальный',
#  'оппонент',
#  'местный',
#  'власть',
#  'кремль',
#  'сам',
#  'помогать',
#  'бороться',
#  'на',
#  'встреча',
#  'с',
#  'один',
#  'замглавы',
#  'администрация',
#  'президент',
#  'вячеслав',
#  'володин',
#  'пригласить',
#  'около',
#  '30',
#  'политолог',
#  'в',
#  'один',
#  'очередь',
#  'тот',
#  'кто',
#  'назначить',
#  'кремль',
#  'наблюдать',
#  'за',
#  'ход',
#  'избирательный',
#  'кампания',
#  'на',
#  'место',
#  'рассказать',
#  'рбк',
#  'несколько',
#  'участник',
#  'встреча',
#  'по',
#  'слово',
#  'собеседник',
#  'от',
#  'администрация',
#  'президент',
#  'помимо',
#  'володин',
#  'быть',
#  'ещё',
#  'руководитель',
#  'внутренний',
#  'политика',
#  'олег',
#  'морозов',
#  'и',
#  'он',
#  'заместитель',
#  'татьяна',
#  'воронов',
#  'повод',
#  'для',
#  'встреча',
#  'стать',
#  'подготовка',
#  'к',
#  'региональный',
#  'выбор',
#  'который',
#  'пройти',
#  '14',
#  'сентябрь',
#  'избирательный',
#  'кампания',
#  'показать',
#  'что',
#  'за',
#  'год',
#  'отсутствие',
#  'прямая',
#  'выбор',
#  'в',
#  'регион',
#  'ухудшиться',
#  'понимание',
#  'внутриполитический',
#  'работа',
#  'губернатор',
#  'отвыкнуть',
#  'от',
#  'публичный',
#  'политика',
#  '—',
#  'этот',
#  'проблема',
#  'обсуждаться',
#  'на',
#  'встреча',
#  'рассказать',
#  'рбк',
#  'руководитель',
#  'близкий',
#  'к',
#  'кремль',
#  'фонд',
#  'исэпить',
#  'дмитрий',
#  'бадовский',
#  'участник',
#  'говорить',
#  'что',
#  'в',
#  'некоторый',
#  'регион',
#  'в',
#  'новость',
#  'вообще',
#  'не',
#  'упоминать',
#  'выбор',
#  'и',
#  'человек',
#  'о',
#  'они',
#  'даже',
#  'не',
#  'знать',
#  'говорить',
#  'директор',
#  'фонд',
#  '«петербургский',
#  'политика»',
#  'михаил',
#  'виноградов',
#  'по',
#  'он',
#  'слово',
#  'губернатор',
#  'считать',
#  'что',
#  'так',
#  'они',
#  'обеспечить',
#  'участие',
#  'в',
#  'выборы',
#  'только',
#  'лояльный',
#  'избиратель',
#  'в',
#  'вина',
#  'региональный',
#  'власть',
#  'ставить',
#  'и',
#  'организация',
#  'досрочный',
#  'голосование',
#  'например',
#  'в',
#  'санкт-петербург',
#  '«справедливый',
#  'россия»',
#  'уже',
#  'заявить',
#  'что',
#  'городской',
#  'власть',
#  'заставлять',
#  'человек',
#  'в',
#  'массовый',
#  'порядок',
#  'досрочно',
#  'участвовать',
#  'в',
#  'выборы',
#  'некоторый',
#  'губернатор',
#  'ошибочно',
#  'считать',
#  'что',
#  'легитимность',
#  'выбор',
#  'определяться',
#  'цифра',
#  'например',
#  'высокий',
#  'явка',
#  'но',
#  'в',
#  'администрация',
#  'президент',
#  'дать',
#  'понять',
#  'что',
#  'легитимность',
#  'определяться',
#  'тем',
#  'насколько',
#  'общество',
#  'и',
#  'местный',
#  'элита',
#  'признавать',
#  'результат',
#  'говорить',
#  'директор',
#  'исэпить',
#  'по',
#  'исследование',
#  'александр',
#  'пожалов',
#  'по',
#  'слово',
#  'другой',
#  'участник',
#  'встреча',
#  'в',
#  'кремль',
#  'обещать',
#  'наказать',
#  'виновный',
#  'в',
#  'нарушение',
#  'на',
#  'досрочный',
#  'голосование',
#  'объяснять',
#  'губернатор',
#  'что',
#  'надо',
#  'работать',
#  'другой',
#  'метод',
#  'быть',
#  'на',
#  'учёба',
#  'который',
#  'администрация',
#  'президент',
#  'в',
#  'это',
#  'год',
#  'вновь',
#  'провести',
#  'для',
#  'глава',
#  'регион',
#  'и',
#  'они',
#  'заместитель',
#  'по',
#  'внутренний',
#  'политика',
#  'говорить',
#  'бадовский',
#  'по',
#  'он',
#  'слово',
#  'чиновник',
#  'нужно',
#  'рассказывать',
#  'как',
#  'общаться',
#  'с',
#  'человек',
#  'что',
#  'такой',
#  'современный',
#  'политический',
#  'язык',
#  'что',
#  'такой',
#  'коммуникация',
#  'и',
#  'устойчивый',
#  'система',
#  'обратный',
#  'связь',
#  '«губернатор',
#  'уже',
#  'сейчас',
#  'объяснять',
#  'что',
#  'надо',
#  'жить',
#  'и',
#  'работать',
#  'в',
#  'иной',
#  'реальность',
#  '—',
#  'реальность',
#  'публичный',
#  'и',
#  'конкурентный',
#  'политики»',
#  '—',
#  'говорить',
#  'руководитель',
#  'исэпить',
#  'в',
#  'кремль',
#  'критиковать',
#  'тот',
#  'губернаторов',
#  'который',
#  'бороться',
#  'с',
#  'кандидат',
#  'не',
#  'представлять',
#  'для',
#  'они',
#  'серьёзный',
#  'угроза',
#  'объяснять',
#  'участвовать',
#  'в',
#  'встреча',
#  'президент',
#  'центр',
#  'политический',
#  'технология',
#  'игорь',
#  'бунин',
#  'поэтому',
#  'особа',
#  'критика',
#  'ранее',
#  'уже',
#  'подвергаться',
#  'нижегородский',
#  'руководитель',
#  'валерий',
#  'шанцев',
#  'и',
#  'липецкий',
#  'губернатор',
#  'олег',
#  'королева',
#  '—',
#  'они',
#  'основной',
#  'оппонент',
#  'не',
#  'быть',
#  'допустить',
#  'до',
#  'выбор',
#  'благодаря',
#  'так',
#  'называть',
#  'муниципальный',
#  'фильтр',
#  'хотя',
#  'по',
#  'слово',
#  'источник',
#  'рбк',
#  'в',
#  'кремль',
#  'тот',
#  'не',
#  'иметь',
#  'никакой',
#  'шанс',
#  'на',
#  'победа',
#  'если',
#  'же',
#  'угроза',
#  'от',
#  'оппонент',
#  'реальный',
#  'то',
#  'администрация',
#  'президент',
#  'сам',
#  'помогать',
#  'губернатор',
#  'решить',
#  'проблема',
#  'отмечать',
#  'бунин',
#  '«правда',
#  'считаться',
#  'что',
#  'хороший',
#  'помогать',
#  'совет',
#  'или',
#  'приезд',
#  'президент',
#  'в',
#  'начало',
#  'сентябрь',
#  'путин',
#  'ездить',
#  'в',
#  'проблемный',
#  'республика',
#  'алтай',
#  'и',
#  'якутия',
#  'но',
#  'в',
#  'особый',
#  'случай',
#  'и',
#  'для',
#  'особо',
#  'святой',
#  'кандидат',
#  'в',
#  'губернатор',
#  'такой',
#  'как',
#  'губернатор',
#  'санкт-петербург',
#  '[георгий',
#  'полтавченко]',
#  'возможный',
#  'и',
#  'помощь',
#  'административный',
#  'ресурсом»',
#  '—',
#  'отмечать',
#  'эксперт',
#  'поэтому',
#  'как',
#  'объяснять',
#  'участник',
#  'встреча',
#  'володин',
#  'высказаться',
#  'за',
#  'сохранение',
#  'муниципальный',
#  'фильтр',
#  'правда',
#  'официальный',
#  'аргументация',
#  '—',
#  'фильтр',
#  'стимулировать',
#  'партия',
#  'участвовать',
#  'в',
#  'выборы',
#  'весь',
#  'уровень',
#  'а',
#  'не',
#  'только',
#  'федеральный',
#  'или',
#  'региональный',
#  'добавлять',
#  'бунин',
#  'на',
#  'пост',
#  'председатель',
#  'совет',
#  'директор',
#  '«российский',
#  'железный',
#  'дорог»',
#  'переизбрать',
#  'управлять',
#  'партнёр',
#  'инвестиционный',
#  'компания',
#  'altera',
#  'capital',
#  'кирилл',
#  'андрос',
#  'решение',
#  'о',
#  'продление',
#  'полномочие',
#  'андросов',
#  'возглавлять',
#  'совет',
#  'директор',
#  'ржд',
#  'с',
#  'сентябрь',
#  '2011',
#  'год',
#  'быть',
#  'принять',
#  'на',
#  'вчерашний',
#  'заседание',
#  'совет',
#  'сообщить',
#  'монополия',
#  'в',
#  'июль',
#  'в',
#  'совет',
#  'директор',
#  'ржд',
#  'войти',
#  'несколько',
#  'новый',
#  'человек',
#  'в',
#  'тот',
#  'число',
#  'сергей',
#  'степашин',
#  'председатель',
#  'наблюдательный',
#  'совет',
#  'фонд',
#  'содействие',
#  'реформирование',
#  'жкх',
#  'близкие',
#  'к',
#  'руководство',
#  'ржд',
#  'источник',
#  'заявлять',
#  'тогда',
#  'рбк',
#  'что',
#  'степашин',
#  'мочь',
#  'стать',
#  'и',
#  'новый',
#  'главый',
#  'совет',
#  'директор',
#  'андрос',
#  'же',
#  '—',
#  'противовес',
#  'президент',
#  'ржд',
#  'владимир',
#  'якунин',
#  'андрос',
#  'известный',
#  'открытый',
#  'критика',
#  'ряд',
#  'идея',
#  'якунин',
#  'в',
#  'частность',
#  'в',
#  'начало',
#  'июль',
#  'голосовать',
#  'на',
#  'заседание',
#  'совет',
#  'директор',
#  'он',
#  'как',
#  'сообщить',
#  'рбк',
#  'два',
#  'источник',
#  'близкие',
#  'к',
#  'совет',
#  'заблокировать',
#  'создание',
#  'российско-белорусско-казахский',
#  'объединить',
#  'транспортно-логистический',
#  'компания',
#  'отлк',
#  'который',
#  'добиваться',
#  'якунин',
#  'якунин',
#  'работать',
#  'без',
#  'переутверждение',
#  'большой',
#  'два',
#  'месяц',
#  '—',
#  'срок',
#  'он',
#  'полномочие',
#  'истечь',
#  '10',
#  'июнь',
#  'а',
#  'новое',
#  'распоряжение',
#  'о',
#  'он',
#  'переназначение',
#  'премьер-министр',
#  'дмитрий',
#  'медведев',
#  'подписать',
#  'только',
#  '25',
#  'август',
#  '«в',
#  'нынешний',
#  'довольно',
#  'сложный',
#  'условие',
#  'нужно',
#  'быть',
#  'продолжить',
#  'работа',
#  'по',
#  'развитие',
#  'сеть',
#  '«российский',
#  'железный',
#  'дорог»',
#  'по',
#  'инвестирование',
#  'средство',
#  'в',
#  'различный',
#  'объект',
#  'открытый',
#  'акционерный',
#  'общество',
#  '«российский',
#  'железный',
#  'дороги»',
#  'естественно',
#  'заботиться',
#  'о',
#  'персонал',
#  'потому',
#  'что',
#  'всё-таки',
#  'это',
#  'самый',
#  'главный',
#  'что',
#  'есть',
#  'у',
#  'общество',
#  'самый',
#  'главный',
#  'богатство',
#  'и',
#  'наверное',
#  'искать',
#  'дополнительный',
#  'источник',
#  'финансирование',
#  'желать',
#  'вы',
#  'успехов»',
#  '—',
#  'заявить',
#  'премьер-министр',
#  'встречаться',
#  'с',
#  'якунин',
#  'в',
#  'день',
#  'он',
#  'назначение',
#  'президент',
#  'ржд',
#  'пообещать',
#  'что',
#  'постараться',
#  'оправдать',
#  'весь',
#  'ожидание',
#  'в',
#  'июнь',
#  'высокопоставленный',
#  'чиновник',
#  'правительство',
#  'говорить',
#  'рбк',
#  'что',
#  'хотя',
#  'глава',
#  'ржд',
#  'достигнуть',
#  'пенсионный',
#  'возраст',
#  'он',
#  '65',
#  'год',
#  'президент',
#  'рф',
#  'владимир',
#  'путин',
#  '«из',
#  'принципа»',
#  'не',
#  'стать',
#  'он',
#  'менять',
#  'пока',
#  'якунин',
#  'оставаться',
#  'под',
#  'санкция',
#  'запад',
#  'в',
#  'март',
#  'министерство',
#  'финансы',
#  'сша',
#  'внести',
#  'якунин',
#  'в',
#  'список',
#  'россиянин',
#  'который',
#  'запретить',
#  'въезд',
#  'в',
#  'страна',
#  'а',
#  'они',
#  'актив',
#  'на',
#  'она',
#  'территория',
#  'должный',
#  'быть',
#  'заморозить',
#  'среди',
#  '20',
#  'человек',
#  'оказаться',
#  'под',
#  'санкция',
#  'только',
#  'четверо',
#  'не',
#  'занимать',
#  'государственный',
#  'пост',
#  'зато',
#  'по',
#  'данные',
#  'минфин',
#  'сша',
#  'составлять',
#  'близкий',
#  'круг',
#  'президент',
#  'россия',
#  'власть',
#  'украина',
#  'так',
#  'и',
#  'не',
#  'определить',
#  'граница',
#  'территория',
#  'который',
#  'верховный',
#  'рада',
#  'наделить',
#  'автономия',
#  'признать',
#  'командование',
#  'антитеррористический',
#  'операция',
#  'в',
#  'настоящее',
#  'время',
#  'повстанец',
#  'контролировать',
#  'около',
#  'треть',
#  'общий',
#  'площадь',
#  'луганский',
#  'и',
#  'донецкий',
#  'область',
#  'но',
#  'они',
#  'граница',
#  'постоянно',
#  'пересматриваться',
#  '–',
#  'несмотря',
#  'на',
#  'объявить',
#  '5',
#  'сентябрь',
#  'прекращение',
#  'огонь',
#  'противостояние',
#  'продолжаться',
#  'в',
#  'ряд',
#  'район',
#  '«в',
#  'закон',
#  'говориться',
#  'о',
#  'территория',
#  'временно',
#  'находиться',
#  'под',
#  'контроль',
#  'ополченец',
#  'однако',
#  'речь',
#  'о',
#  'определение',
#  'граница',
#  'этот',
#  'территория',
#  'пока',
#  'не',
#  'идет»',
#  '–',
#  'заявить',
#  'в',
#  'четверг',
#  'на',
#  'брифинг',
#  'официальный',
#  'представитель',
#  'совет',
#  'национальный',
#  'безопасность',
#  'и',
#  'оборона',
#  'андрей',
#  'лысенко',
#  'по',
#  'он',
#  'слово',
#  'пока',
#  'действовать',
#  'режим',
#  'прекращение',
#  'огонь',
#  'украинский',
#  'армия',
#  'рассчитывать',
#  '«укрепить',
#  'силы»',
#  'но',
#  '«всё',
#  'что',
#  'произойти',
#  'в',
#  'дальнейший',
#  '–',
#  'неизвестно»',
#  'принять',
#  'верховный',
#  'рада',
#  'в',
#  'вторник',
#  'закон',
#  'оговаривать',
#  'что',
#  'определять',
#  'граница',
#  'территория',
#  'который',
#  'придать',
#  'особый',
#  'статус',
#  'должный',
#  'руководитель',
#  'антитеррористический',
#  'центр',
#  'при',
#  'служба',
#  'безопасность',
#  'украина',
#  'закон',
#  'который',
#  'собираться',
#  'оспаривать',
#  'в',
#  'конституционный',
#  'суд',
#  'фракция',
#  '«батькивщина»',
#  'юлия',
#  'тимошенко',
#  'быть',
#  'поправить',
#  'как',
#  'утверждать',
#  'депутат',
#  'и',
#  'бывший',
#  'министр',
#  'оборона',
#  'анатолий',
#  'гриценко',
#  'в',
#  'тот',
#  'документ',
#  'который',
#  'он',
#  'коллега',
#  'получить',
#  'на',
#  'рука',
#  'в',
#  'вторник',
#  'перед',
#  'голосование',
#  'указываться',
#  'что',
#  'граница',
#  'район',
#  'с',
#  'особый',
#  'статус',
#  'определять',
#  'верхов\xadный',
#  'рада',
#  'сам',
#  'ополченец',
#  'считать',
#  'территория',
#  '«народный',
#  'республик»',
#  'весь',
#  'территория',
#  'донбасс',
#  '«мы',
#  'с',
#  'свой',
#  'сторона',
#  'вести',
#  'речь',
#  'о',
#  'территория',
#  'бывший',
#  'донецкий',
#  'и',
#  'луганский',
#  ...]

# %% [markdown]
# Так-то лучше. Теперь инициализируем объект класса BigramCollocationFinder, который за нас выделяет в массиве слов биграммы и считает для них всякие характеристики.

# %%
finder = BigramCollocationFinder.from_words(words_tagged)

# %% [markdown]
# Распечатаем, например, 10 самых сильных коллокаций по версии метрики Pointwise Mutual Information.
#
# Полный набор доступных мер оценки коллокационной связи см. [здесь](http://www.nltk.org/_modules/nltk/metrics/association.html)

# %%
finder.nbest(bigram_measures.pmi, 10)
# Out:
# [('"закручивание', 'гаек"'),
#  ('+', '4,65%»'),
#  ('0,58', 'евро»'),
#  ('12–15', 'контрольно-надзорный'),
#  ('1400', 'полувагон'),
#  ('1577', 'lada'),
#  ('17,2%', 'заболевание'),
#  ('18,49%', 'ppf'),
#  ('2,68%', '«сделка'),
#  ('2010–2020', 'годы)»')]

# %% [markdown]
# Видим, что среди мнимых коллокаций попадается много мусора. Попробуем от него избавиться, установив для finder'а фильтр по частотности. Таким образом мы отсеем биграммы, которые встретились в корпусе 1 или 2 раза.

# %%
finder.apply_freq_filter(3)
finder.nbest(bigram_measures.pmi, 10)
# Out:
# [('kyodo', 'news'),
#  ('ponars', 'eurasia'),
#  ('small', 'letters'),
#  ('synovate', 'comcon'),
#  ('«наблюдатель', 'петербурга»'),
#  ('«негативный', 'консенсус»'),
#  ('«утрата', 'доверия»'),
#  ('андерс', 'фог'),
#  ('гаснуть', '«выборы»'),
#  ('goltsblat', 'blp')]

# %% [markdown]
# Так-то лучше, но ещё есть, что улучшать. Например, можем удалить из коллокаций стоп-слова (предлоги, союзы, местоимения) и просто слова короче 3 символов.
#
# Заодно помимо pmi попробуем ещё другую метрику - Log-Likelihood.

# %%
stopwords = nltk.corpus.stopwords.words('russian')
finder.apply_word_filter(lambda w: len(w) < 3 or w.lower() in stopwords)
finder.nbest(bigram_measures.likelihood_ratio, 10)
# Out:
# [('миллиард', 'рубль'),
#  ('2014', 'год'),
#  ('2013', 'год'),
#  ('2015', 'год'),
#  ('точка', 'зрение'),
#  ('сказать', 'рбк'),
#  ('миллион', 'рубль'),
#  ('владимир', 'путин'),
#  ('«единый', 'россии»'),
#  ('афк', '«система»')]

# %% [markdown]
# До сих пор мы распечатывали N биграмм, имеющих наибольшую меру коллокационной связи. Но можно распечатать и все биграммы и их оценки.
#
# Допустим, мы хотим распечатать просто частоту биграммы в корпусе.

# %%
scored_bigrams = finder.score_ngrams(bigram_measures.raw_freq)
sorted(scored_bigrams, key = lambda x: x[1])
# Out:
# [(('$1,5', 'миллиард'), 1.6956624953369282e-05),
#  (('$10', 'миллиард'), 1.6956624953369282e-05),
#  (('$25', 'миллион'), 1.6956624953369282e-05),
#  (('$30', 'миллион'), 1.6956624953369282e-05),
#  (('$50', 'миллиард'), 1.6956624953369282e-05),
#  (('0,5', 'п.п'), 1.6956624953369282e-05),
#  (('1,5', 'миллиард'), 1.6956624953369282e-05),
#  (('1,5', 'триллион'), 1.6956624953369282e-05),
#  (('1,6', 'миллиард'), 1.6956624953369282e-05),
#  (('1,8', 'миллиард'), 1.6956624953369282e-05),
#  (('120', 'тысяча'), 1.6956624953369282e-05),
#  (('19.00', 'мск'), 1.6956624953369282e-05),
#  (('1992', 'год'), 1.6956624953369282e-05),
#  (('1998', 'год'), 1.6956624953369282e-05),
#  (('2,3', 'миллиард'), 1.6956624953369282e-05),
#  (('2,99', 'миллиард'), 1.6956624953369282e-05),
#  (('200', 'километр'), 1.6956624953369282e-05),
#  (('2012–2013', 'год'), 1.6956624953369282e-05),
#  (('2017', 'годов»'), 1.6956624953369282e-05),
#  (('2030', 'год'), 1.6956624953369282e-05),
#  (('3,8', 'миллиард'), 1.6956624953369282e-05),
#  (('300', 'миллиард'), 1.6956624953369282e-05),
#  (('311', 'мвт'), 1.6956624953369282e-05),
#  (('365', 'миллион'), 1.6956624953369282e-05),
#  (('400', 'миллион'), 1.6956624953369282e-05),
#  (('624', 'тысяча'), 1.6956624953369282e-05),
#  (('700', 'тысяча'), 1.6956624953369282e-05),
#  (('80%', 'российский'), 1.6956624953369282e-05),
#  (('82-го', 'судоремонтный'), 1.6956624953369282e-05),
#  (('9,2', 'миллиард'), 1.6956624953369282e-05),
#  (('en+', 'group'), 1.6956624953369282e-05),
#  (('goltsblat', 'blp'), 1.6956624953369282e-05),
#  (('group', 'олег'), 1.6956624953369282e-05),
#  (('ing', 'дмитрий'), 1.6956624953369282e-05),
#  (('jsw', 'steel'), 1.6956624953369282e-05),
#  (('kyodo', 'news'), 1.6956624953369282e-05),
#  (('lbbw', 'bank'), 1.6956624953369282e-05),
#  (('letters', 'виталий'), 1.6956624953369282e-05),
#  (('ponars', 'eurasia'), 1.6956624953369282e-05),
#  (('sanoma', 'corp'), 1.6956624953369282e-05),
#  (('small', 'letters'), 1.6956624953369282e-05),
#  (('swift', 'bloomberg'), 1.6956624953369282e-05),
#  (('политический', 'обстановка'), 1.6956624953369282e-05),
#  (('политический', 'причина'), 1.6956624953369282e-05),
#  (('политолог', 'владимир'), 1.6956624953369282e-05),
#  (('политтехнология', 'игорь'), 1.6956624953369282e-05),
#  (('полномочие', 'председатель'), 1.6956624953369282e-05),
#  (('полный', 'запрет'), 1.6956624953369282e-05),
#  (('положение', 'закон'), 1.6956624953369282e-05),
#  (('положение', 'законопроект'), 1.6956624953369282e-05),
#  (('положительный', 'решение'), 1.6956624953369282e-05),
#  (('получить', 'возможность'), 1.6956624953369282e-05),
#  (('получить', 'кредит'), 1.6956624953369282e-05),
#  (('получить', 'лицензия'), 1.6956624953369282e-05),
#  (('получить', 'новый'), 1.6956624953369282e-05),
#  (('получить', 'поддержка'), 1.6956624953369282e-05),
#  (('пользоваться', 'интернет'), 1.6956624953369282e-05),
#  ...]

# %% [markdown]
# Допустим, нас интересуют биграммы, частотность которых больше, чем какой-то порог. This is also possible in ntlk.

# %%
frequent_bigrams = finder.above_score(bigram_measures.raw_freq, 0.0005)
for b in frequent_bigrams:
    print(b)
# Out:
# ('миллиард', 'рубль')
# ('2014', 'год')
# ('2013', 'год')
# ('2015', 'год')
# ('миллион', 'рубль')
# ('сказать', 'рбк')
# ('это', 'год')

# %% [markdown]
# Все, что мы до настоящего момента делали на материале биграмм, можно сделать и с триграммами. В nltk для них доступны аналогичные функции.
#
# For your interest: в nltk есть ещё и функции для 4-грамм, которые там называются Quadgram.

# %%
tr_finder = TrigramCollocationFinder.from_words(words_tagged)
tr_finder.apply_word_filter(lambda w: len(w) < 3 or w.lower() in stopwords)
tr_finder.apply_freq_filter(10)
tr_finder.nbest(trigram_measures.likelihood_ratio, 10)
# Out:
# [('квартал', '2014', 'год'),
#  ('полугодие', '2014', 'год'),
#  ('конец', '2014', 'год'),
#  ('апрель', '2014', 'год'),
#  ('начало', '2014', 'год'),
#  ('сентябрь', '2014', 'год'),
#  ('точка', 'зрение', 'автор'),
#  ('сказать', 'рбк', 'представитель'),
#  ('президент', 'владимир', 'путин'),
#  ('сказать', 'рбк', 'источник')]

# %% [markdown]
# Ну ок. Научились мы извлекать коллокации, но бездумно это делать не хочется. Как же это работает?
#
# На самом деле, когда мы создаем объект класса CollocationFinder, он берет все биграммы/триграммы/whatever в наших данных и считает для них для всех несколько характеристик.
#
# Затем, когда мы запрашиваем какую-то меру коллокационной связи, nltk берет эти характеристики и считает нужную нам меру.
#
# Что это за характеристики?

# %% [markdown]
# На самом деле nltk считает для каждой пары слов в массиве такую матрицу: частота слова1 в корпусе, частота слова2 в корпусе, частота совместной встречаемости слова1 и слова2 в корпусе, общее количество биграмм в корпусе.
#
#         w1    ~w1
#      ------ ------
#  w2 | n_ii | n_oi | = n_xi
#      ------ ------
# ~w2 | n_io | n_oo |
#      ------ ------
#      = n_ix        TOTAL = n_xx
#
# То есть для биграмм мы считаем данные такой матрицы: (n_ii, (n_ix, n_xi), n_xx) и все их складываем в массив. Затем, когда мы запрашиваем коллокации с какими-то характеристиками, nltk быстренько их подсчитывает, поскольку готовые данные у него уже есть, и отдает нам результат.
#
# Обладая этим сакральным знанием, мы можем понаблюдать, как себя ведут различные коэффициенты на разных выдуманных данных.

# %%
print('%0.4f' % bigram_measures.student_t(8, (15828, 4675), 14307668))
# Out:
# 0.9999

# %%
print('%0.4f' % bigram_measures.student_t(20, (42, 20), 14307668))
# Out:
# 4.4721

# %%
print('%0.2f' % bigram_measures.chi_sq(8, (15828, 4675), 14307668))
# Out:
# 1.55

# %%
print('%0.0f' % bigram_measures.chi_sq(59, (67, 65), 571007))
# Out:
# 456400

# %% [markdown]
# Ну в общем, понятно.

# %%
print('%0.2f' % bigram_measures.likelihood_ratio(110, (2552, 221), 31777))
print('%0.2f' % bigram_measures.likelihood_ratio(8, (13, 32), 31777))
print('%0.2f' % bigram_measures.pmi(20, (42, 20), 14307668))
print('%0.2f' % bigram_measures.pmi(20, (15019, 15629), 14307668))
# Out:
# 270.72
# 95.29
# 18.38
# 0.29

# %% [markdown]
# Теперь мы умеем считать для коллокаций различные меры коллокационной связи, понимаем, как это работает, но в большинстве исследовательских задач мы не используем готовые алгоритмы, а как-то их модифицируем для своей конкретной задачи. Поэтому возникает необходимость оценить качество работы нашего алгоритма. Для этого можно сравнить результаты с золотым стандартом при помощи коэффициента ранговой корреляции Спирмена.
#
# Ранговой - потому что учитывается порядок следования результатов друг за другом.
# Корреляции - потому что мы считаем, насколько два списка с результатами друг с другом коррелируют.
#
# В nltk есть модуль nltk.metrics, который умеет разные метрики считать.
# Импортируем функции для нужной нам метрики. В частности, есть функции rank_from_sequence() и rank_from_scores(), которые превращают массивы с результатами в ранги.

# %%
from nltk.metrics.spearman import *
results_list = ['item1', 'item2', 'item3', 'item4', 'item5']
print(list(ranks_from_sequence(results_list)))
# Out:
# [('item1', 0), ('item2', 1), ('item3', 2), ('item4', 3), ('item5', 4)]

# %% [markdown]
# Для списков объектов, для которых у нас имеются оценки, можно задавать промежуток оценки, в течение которого мы считаем ранг неизменным.

# %%
results_scored = [('item1', 50.0), ('item2', 40.0), ('item3', 38.0), ('item4', 35.0), ('item5', 14.0)]
print(list(ranks_from_scores(results_scored, rank_gap=5)))
# Out:
# [('item1', 0), ('item2', 1), ('item3', 1), ('item4', 1), ('item5', 4)]

# %% [markdown]
# Но довольно слов: вот у нас список с некоторыми результатами, посчитаем корреляцию.

# %%
results_list2 = ['item2', 'item3', 'item1', 'item5', 'item4']

# %% [markdown]
# Корреляция золотого стандарта самого с собой.

# %%
print('%0.1f' % spearman_correlation(ranks_from_sequence(results_list), ranks_from_sequence(results_list)))
# Out:
# 1.0

# %% [markdown]
# Корреляция золотого стандарта с ним самим, но в обратном порядке.

# %%
print('%0.1f' % spearman_correlation(ranks_from_sequence(reversed(results_list)), ranks_from_sequence(results_list)))
# Out:
# -1.0

# %% [markdown]
# Корреляция между золотым стандартом и нашими данными.

# %%
print('%0.1f' % spearman_correlation(ranks_from_sequence(results_list), ranks_from_sequence(results_list2)))
# Out:
# 0.6
