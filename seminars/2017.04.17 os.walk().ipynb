# %% [markdown]
# # Хождение по папкам
#
# Давайте вспомним функцию `os.listdir()`, которую мы узнали на прошлом занятии. Можно вывести список файлов в текущей папке:

# %%
import os
os.listdir('.')
# Out:
# ['2017.04.10 Работа с файлами и папками.ipynb',
#  '2017.04.03 Повторение, comprehensions, format.ipynb',
#  '1_Лекция_Лингвистические электронные ресурсы.pdf',
#  '2017.04.17 os.walk().ipynb',
#  '.ipynb_checkpoints',
#  'corpus_freq.xlsx',
#  '2539.xml',
#  'BAWE',
#  'Regex.pdf',
#  'top_folder']

# %% [markdown]
# Можно вывести список файлов в папке уровнем выше:

# %%
os.listdir('..')
# Out:
# ['kili.zip',
#  'hw_repos',
#  'spoken.txt',
#  'tihiyd.txt',
#  'KILI_nu.xlsx',
#  'original',
#  'ann2rnc_git.py~',
#  'repositories Github (Responses).ods',
#  'lat_rus.txt',
#  'Google-Spreadsheets-basic.md',
#  'example_repo',
#  'about_life_stressed.2.txt',
#  'скрины - гуглтаблицы',
#  'transcripts',
#  'prog_grades.ods',
#  'sample_video_transcript.2.txt',
#  'rnc',
#  'brat2rnc',
#  'КИЛИ и программирование.pdf',
#  'stressed',
#  'на бумажке.docx',
#  'google-spreadsheets images',
#  'sample_ana.txt',
#  'output.txt',
#  'prog_grades.xlsx',
#  'repetition.txt',
#  'raw_texts',
#  'news.txt',
#  'rur.txt',
#  'example_webpage.html',
#  'speakers',
#  'Vojna i mir. Tom 1.txt',
#  '20160905_Компьютерные группы - 1 курс.xlsx',
#  'README.md',
#  'seminars',
#  '.git',
#  'sample_speakers.txt',
#  'images',
#  'corpus-xml-example.txt']

# %% [markdown]
# В домашнем задании многие интересовались, нужно ли уметь заходить в папки и смотреть, какие файлы в них лежат. На самом деле, с питоном сделать это очень легко. Для этого используется другая функция, которая называется `os.walk()`. Как следует из её названия, она умееет "гулять по папкам".

# %%
file_tree = os.walk('.')
file_tree
# Out:
# <generator object walk at 0x7f4ec41eceb8>

# %% [markdown]
# Эта функция устроена немного сложнее, чем те функции, с которыми мы работали раньше. Она возвращает пользователю целых три объекта -- `root, dirs и files`. В переменной `root` лежит путь к текущей папке, в переменной `dirs` лежат все папки, лежащие в текущей папке, а в переменной `files` лежат все файлы в текущей папке.
#
# Эту функцию нужно вызывать в цикле `for`, и тогда на каждом шаге цикла она будет переходить в новую папку, и переменные `root, dirs, files` будут модифицироваться соответствующим образом.

# %%
for d in file_tree:
    print(d)
# Out:
# ('.', ['.ipynb_checkpoints', 'BAWE', 'top_folder'], ['2017.04.10 Работа с файлами и папками.ipynb', '2017.04.03 Повторение, comprehensions, format.ipynb', '1_Лекция_Лингвистические электронные ресурсы.pdf', '2017.04.17 os.walk().ipynb', 'corpus_freq.xlsx', '2539.xml', 'Regex.pdf'])
# ('./.ipynb_checkpoints', [], ['2017.04.17 os.walk()-checkpoint.ipynb', '2017.04.10 Работа с файлами и папками-checkpoint.ipynb'])
# ('./BAWE', ['documentation', 'CORPUS_ASCII', 'CORPUS_TXT', 'CORPUS_UTF-8'], [])
# ('./BAWE/documentation', [], ['BAWE.documentation.pdf', 'BAWE.xls', 'BAWE.pdf'])
# ('./BAWE/CORPUS_ASCII', [], ['0057a.xml', '6090e.xml', '6998b.xml', '0397b.xml', '0262e.xml', '6129g.xml', '3008b.xml', '6197g.xml', '6042a.xml', '3091j.xml', '3008d.xml', '6084c.xml', '0124d.xml', '6076a.xml', '3029a.xml', '0179c.xml', '0172a.xml', '0320a.xml', '0237c.xml', '0014d.xml', '6055d.xml', '0314c.xml', '0310e.xml', '0129h.xml', '3027a.xml', '0389d.xml', '0138c.xml', '3108d.xml', '0303i.xml', '0393a.xml', '6020c.xml', '3147d.xml', '0027c.xml', '0202e.xml', '0135h.xml', '3034c.xml', '0215c.xml', '0130e.xml', '0237d.xml', '6008f.xml', '3019c.xml', '3085a.xml', '6104c.xml', '0202b.xml', '3030a.xml', '0388h.xml', '0004a.xml', '3045e.xml', '6015f.xml', '6050a.xml', '3017c.xml', '0144c.xml', '6110c.xml', '0265e.xml', '0039f.xml', '0252l.xml', '6194a.xml', '0055b.xml', '6215b.xml', '0290c.xml', '6027c.xml', '6146f.xml', '0406d.xml', '6090f.xml', '0056b.xml', '6034a.xml', '0306h.xml', '6159e.xml', '0194i.xml', '0263d.xml', '0197a.xml', '0247a.xml', '6111e.xml', '3018e.xml', '6009a.xml', '3134f.xml', '0023c.xml', '0081d.xml', '0196a.xml', '3061b.xml', '3053b.xml', '6102a.xml', '6206a.xml', '0020d.xml', '0250b.xml', '6011i.xml', '3125c.xml', '0061h.xml', '6131o.xml', '0027a.xml', '3012c.xml', '0058f.xml', '0036a.xml', '3017b.xml', '3080b.xml', '0003c.xml', '6011h.xml', '6161c.xml', '0280d.xml', '0021b.xml', '6108h.xml', '6029a.xml', '3040d.xml', '0208g.xml', '6123f.xml', '0169e.xml', '0058g.xml', '6143b.xml', '0246a.xml', '6168b.xml', '0388a.xml', '0275c.xml', '3025a.xml', '6087k.xml', '3075b.xml', '0127c.xml', '0081c.xml', '0390c.xml', '0090b.xml', '6180d.xml', '0031a.xml', '3072c.xml', '6067e.xml', '0354b.xml', '3042c.xml', '0191c.xml', '3032f.xml', '6014b.xml', '3017a.xml', '6017h.xml', '3085c.xml', '0408a.xml', '6122i.xml', '0407d.xml', '0179h.xml', '6094a.xml', '0188d.xml', '0254j.xml', '0070a.xml', '0137m.xml', '3008i.xml', '0398c.xml', '0408e.xml', '6013c.xml', '0350e.xml', '0347b.xml', '3082a.xml', '0287c.xml', '0310d.xml', '3034e.xml', '0112a.xml', '0384a.xml', '6172d.xml', '0289e.xml', '0144e.xml', '0206f.xml', '0075l.xml', '6193c.xml', '6139a.xml', '6198d.xml', '0391c.xml', '0062b.xml', '0169f.xml', '0179d.xml', '6171g.xml', '0405a.xml', '6113d.xml', '0316b.xml', '0252b.xml', '0309a.xml', '3095a.xml', '0153e.xml', '0370b.xml', '0208a.xml', '6129a.xml', '6044b.xml', '3001c.xml', '0122a.xml', '3147a.xml', '0424d.xml', '0079a.xml', '0269d.xml', '0201a.xml', '0222a.xml', '0329g.xml', '3064e.xml', '3101g.xml', '0354a.xml', '0249g.xml', '3140d.xml', '6087e.xml', '0055e.xml', '6147a.xml', '0193a.xml', '0061c.xml', '0070c.xml', '0358d.xml', '6153d.xml', '0394a.xml', '6032a.xml', '0073b.xml', '3030b.xml', '0212d.xml', '0131a.xml', '0338a.xml', '0159c.xml', '3064g.xml', '0315a.xml', '0364f.xml', '6114b.xml', '6016l.xml', '6005c.xml', '0114i.xml', '3140b.xml', '6008d.xml', '3135b.xml', '0262g.xml', '6200f.xml', '6167e.xml', '0209c.xml', '6146e.xml', '0238c.xml', '0291b.xml', '0276d.xml', '0032c.xml', '0029n.xml', '0034d.xml', '0390d.xml', '6110a.xml', '0358e.xml', '6197j.xml', '3089d.xml', '0389g.xml', '3042b.xml', '0058e.xml', '6129d.xml', '0098c.xml', '0354e.xml', '0094d.xml', '6169e.xml', '6097e.xml', '0310c.xml', '0139a.xml', '6112e.xml', '0284d.xml', '3069d.xml', '6211i.xml', '3063c.xml', '0129e.xml', '0324b.xml', '6214a.xml', '0306c.xml', '0342d.xml', '0029l.xml', '0410b.xml', '0249j.xml', '0252k.xml', '0224e.xml', '0065g.xml', '6202a.xml', '6036c.xml', '3157c.xml', '3012d.xml', '6038d.xml', '0405b.xml', '6157b.xml', '0019f.xml', '3001a.xml', '0011c.xml', '0021c.xml', '0202i.xml', '0320e.xml', '6033b.xml', '0203c.xml', '0362c.xml', '6197e.xml', '6060b.xml', '6016k.xml', '6001a.xml', '0410e.xml', '6171a.xml', '0357a.xml', '0249d.xml', '3034b.xml', '6131q.xml', '0228f.xml', '0155a.xml', '0260f.xml', '0407b.xml', '0127d.xml', '3141b.xml', '0146d.xml', '0424a.xml', '6027d.xml', '3048a.xml', '0064c.xml', '0384c.xml', '0409a.xml', '3013c.xml', '0055d.xml', '0163a.xml', '0065a.xml', '0245a.xml', '6094b.xml', '0315e.xml', '0215e ...
# ('./BAWE/CORPUS_TXT', [], ['0003h.txt', '6211e.txt', '0063b.txt', '0171b.txt', '6131n.txt', '6085j.txt', '6197i.txt', '0415j.txt', '0188g.txt', '6101j.txt', '3095d.txt', '6008g.txt', '3032e.txt', '0258j.txt', '6197a.txt', '0202a.txt', '0232b.txt', '0422c.txt', '0138b.txt', '0253b.txt', '6079a.txt', '0340c.txt', '6193c.txt', '0019f.txt', '0004c.txt', '0224g.txt', '0297a.txt', '0253a.txt', '3019g.txt', '6022c.txt', '0055e.txt', '0315b.txt', '3131a.txt', '0181a.txt', '3101f.txt', '0183e.txt', '0243d.txt', '6004f.txt', '3024b.txt', '0057c.txt', '6161c.txt', '0190d.txt', '0152b.txt', '0057e.txt', '6091d.txt', '6016g.txt', '0280h.txt', '0249h.txt', '0129c.txt', '0150c.txt', '3006j.txt', '6010c.txt', '6153a.txt', '0129h.txt', '0244g.txt', '3045b.txt', '0153e.txt', '0024a.txt', '0389c.txt', '0120e.txt', '0246h.txt', '6210e.txt', '3032c.txt', '0171c.txt', '0423e.txt', '0114a.txt', '6050a.txt', '0010d.txt', '6170c.txt', '0343d.txt', '6200c.txt', '3096a.txt', '6182f.txt', '0354c.txt', '3080b.txt', '6111a.txt', '6182b.txt', '0347g.txt', '0199b.txt', '0219a.txt', '0252b.txt', '6013c.txt', '6033c.txt', '0354d.txt', '6005c.txt', '6124b.txt', '3076c.txt', '0428a.txt', '3147b.txt', '0024e.txt', '6094a.txt', '6086i.txt', '0200f.txt', '6028a.txt', '6137a.txt', '0020g.txt', '0252s.txt', '0245i.txt', '6130e.txt', '0234e.txt', '3138c.txt', '0254a.txt', '0310b.txt', '0388b.txt', '0258h.txt', '0382c.txt', '6102e.txt', '0179h.txt', '0363d.txt', '0165d.txt', '6159f.txt', '0019i.txt', '6021c.txt', '0342c.txt', '0245b.txt', '0311f.txt', '6016l.txt', '3027a.txt', '6134b.txt', '0112c.txt', '3138b.txt', '6084a.txt', '6073b.txt', '0146e.txt', '0094d.txt', '6110b.txt', '0029p.txt', '0112f.txt', '3108e.txt', '6090k.txt', '6012d.txt', '6013a.txt', '0362b.txt', '0316c.txt', '0431a.txt', '6038a.txt', '0348d.txt', '0320b.txt', '6027b.txt', '6143c.txt', '3019c.txt', '3017a.txt', '6021e.txt', '0410d.txt', '0126a.txt', '6146f.txt', '3020b.txt', '6159i.txt', '0271b.txt', '3057a.txt', '0100b.txt', '0137h.txt', '3049b.txt', '6010d.txt', '6203i.txt', '6082a.txt', '0165c.txt', '3124a.txt', '0077a.txt', '6012j.txt', '0312j.txt', '6173b.txt', '6103a.txt', '3143b.txt', '6021a.txt', '6113d.txt', '0209d.txt', '0119f.txt', '0280i.txt', '3092e.txt', '0034d.txt', '0082g.txt', '6112g.txt', '0411a.txt', '3059b.txt', '6168e.txt', '0075e.txt', '0035b.txt', '0126f.txt', '0200d.txt', '0312g.txt', '6137b.txt', '0020d.txt', '0069a.txt', '6111d.txt', '0306h.txt', '6015c.txt', '0024d.txt', '0247a.txt', '6014c.txt', '0340a.txt', '3052e.txt', '6150c.txt', '0396a.txt', '6100d.txt', '6086g.txt', '0112b.txt', '6180b.txt', '0307a.txt', '0041a.txt', '0023a.txt', '3126c.txt', '0364g.txt', '6023c.txt', '0177b.txt', '0062a.txt', '0010a.txt', '6170a.txt', '0029c.txt', '6103i.txt', '0063a.txt', '0058e.txt', '0023e.txt', '0034b.txt', '0082d.txt', '6090c.txt', '0039f.txt', '3101h.txt', '0404a.txt', '0144a.txt', '0274a.txt', '0329g.txt', '3075a.txt', '6114b.txt', '0014c.txt', '0130d.txt', '0263i.txt', '0252f.txt', '3130c.txt', '6211c.txt', '3048b.txt', '6206e.txt', '3159a.txt', '0067a.txt', '0348e.txt', '3110d.txt', '0181c.txt', '0407d.txt', '0324b.txt', '3064a.txt', '0249e.txt', '0147a.txt', '6210h.txt', '0255d.txt', '6113a.txt', '6082o.txt', '0323b.txt', '0281b.txt', '0430a.txt', '0188f.txt', '6203d.txt', '3002a.txt', '0423c.txt', '6210i.txt', '3109a.txt', '3052c.txt', '0226b.txt', '0114g.txt', '0389f.txt', '0358c.txt', '0250a.txt', '0252n.txt', '0143c.txt', '0276f.txt', '6124a.txt', '0290a.txt', '0234f.txt', '0238d.txt', '0150b.txt', '0401b.txt', '0322a.txt', '0032b.txt', '0125a.txt', '0314f.txt', '6006f.txt', '0376a.txt', '0269d.txt', '0267c.txt', '0244n.txt', '0281a.txt', '3032h.txt', '6201g.txt', '6210j.txt', '0294a.txt', '6129i.txt', '0318g.txt', '6012b.txt', '0146g.txt', '0354a.txt', '3141b.txt', '0016b.txt', '0341g.txt', '3060d.txt', '6201d.txt', '6202b.txt', '6033b.txt', '6145a.txt', '0130b.txt', '6010e.txt', '0011a.txt', '6025b.txt', '6172a.txt', '0405d.txt', '0066a.txt', '3080e.txt', '3082b.t ...
# ('./BAWE/CORPUS_UTF-8', [], ['0057a.xml', '6090e.xml', '6998b.xml', '0397b.xml', '0262e.xml', '6129g.xml', '3008b.xml', '6197g.xml', '6042a.xml', '3091j.xml', '3008d.xml', '6084c.xml', '0124d.xml', '6076a.xml', '3029a.xml', '0179c.xml', '0172a.xml', '0320a.xml', '0237c.xml', '0014d.xml', '6055d.xml', '0314c.xml', '0310e.xml', '0129h.xml', '3027a.xml', '0389d.xml', '0138c.xml', '3108d.xml', '0303i.xml', '0393a.xml', '6020c.xml', '3147d.xml', '0027c.xml', '0202e.xml', '0135h.xml', '3034c.xml', '0215c.xml', '0130e.xml', '0237d.xml', '6008f.xml', '3019c.xml', '3085a.xml', '6104c.xml', '0202b.xml', '3030a.xml', '0388h.xml', '0004a.xml', '3045e.xml', '6015f.xml', '6050a.xml', '3017c.xml', '0144c.xml', '6110c.xml', '0265e.xml', '0039f.xml', '0252l.xml', '6194a.xml', '0055b.xml', '6215b.xml', '0290c.xml', '6027c.xml', '6146f.xml', '0406d.xml', '6090f.xml', '0056b.xml', '6034a.xml', '0306h.xml', '6159e.xml', '0194i.xml', '0263d.xml', '0197a.xml', '0247a.xml', '6111e.xml', '3018e.xml', '6009a.xml', '3134f.xml', '0023c.xml', '0081d.xml', '0196a.xml', '3061b.xml', '3053b.xml', '6102a.xml', '6206a.xml', '0020d.xml', '0250b.xml', '6011i.xml', '3125c.xml', '0061h.xml', '6131o.xml', '0027a.xml', '3012c.xml', '0058f.xml', '0036a.xml', '3017b.xml', '3080b.xml', '0003c.xml', '6011h.xml', '6161c.xml', '0280d.xml', '0021b.xml', '6108h.xml', '6029a.xml', '3040d.xml', '0208g.xml', '6123f.xml', '0169e.xml', '0058g.xml', '6143b.xml', '0246a.xml', '6168b.xml', '0388a.xml', '0275c.xml', '3025a.xml', '6087k.xml', '3075b.xml', '0127c.xml', '0081c.xml', '0390c.xml', '0090b.xml', '6180d.xml', '0031a.xml', '3072c.xml', '6067e.xml', '0354b.xml', '3042c.xml', '0191c.xml', '3032f.xml', '6014b.xml', '3017a.xml', '6017h.xml', '3085c.xml', '0408a.xml', '6122i.xml', '0407d.xml', '0179h.xml', '6094a.xml', '0188d.xml', '0254j.xml', '0070a.xml', '0137m.xml', '3008i.xml', '0398c.xml', '0408e.xml', '6013c.xml', '0350e.xml', '0347b.xml', '3082a.xml', '0287c.xml', '0310d.xml', '3034e.xml', '0112a.xml', '0384a.xml', '6172d.xml', '0289e.xml', '0144e.xml', '0206f.xml', '0075l.xml', '6193c.xml', '6139a.xml', '6198d.xml', '0391c.xml', '0062b.xml', '0169f.xml', '0179d.xml', '6171g.xml', '0405a.xml', '6113d.xml', '0316b.xml', '0252b.xml', '0309a.xml', '3095a.xml', '0153e.xml', '0370b.xml', '0208a.xml', '6129a.xml', '6044b.xml', '3001c.xml', '0122a.xml', '3147a.xml', '0424d.xml', '0079a.xml', '0269d.xml', '0201a.xml', '0222a.xml', '0329g.xml', '3064e.xml', '3101g.xml', '0354a.xml', '0249g.xml', '3140d.xml', '6087e.xml', '0055e.xml', '6147a.xml', '0193a.xml', '0061c.xml', '0070c.xml', '0358d.xml', '6153d.xml', '0394a.xml', '6032a.xml', '0073b.xml', '3030b.xml', '0212d.xml', '0131a.xml', '0338a.xml', '0159c.xml', '3064g.xml', '0315a.xml', '0364f.xml', '6114b.xml', '6016l.xml', '6005c.xml', '0114i.xml', '3140b.xml', '6008d.xml', '3135b.xml', '0262g.xml', '6200f.xml', '6167e.xml', '0209c.xml', '6146e.xml', '0238c.xml', '0291b.xml', '0276d.xml', '0032c.xml', '0029n.xml', '0034d.xml', '0390d.xml', '6110a.xml', '0358e.xml', '6197j.xml', '3089d.xml', '0389g.xml', '3042b.xml', '0058e.xml', '6129d.xml', '0098c.xml', '0354e.xml', '0094d.xml', '6169e.xml', '6097e.xml', '0310c.xml', '0139a.xml', '6112e.xml', '0284d.xml', '3069d.xml', '6211i.xml', '3063c.xml', '0129e.xml', '0324b.xml', '6214a.xml', '0306c.xml', '0342d.xml', '0029l.xml', '0410b.xml', '0249j.xml', '0252k.xml', '0224e.xml', '0065g.xml', '6202a.xml', '6036c.xml', '3157c.xml', '3012d.xml', '6038d.xml', '0405b.xml', '6157b.xml', '0019f.xml', '3001a.xml', '0011c.xml', '0021c.xml', '0202i.xml', '0320e.xml', '6033b.xml', '0203c.xml', '0362c.xml', '6197e.xml', '6060b.xml', '6016k.xml', '6001a.xml', '0410e.xml', '6171a.xml', '0357a.xml', '0249d.xml', '3034b.xml', '6131q.xml', '0228f.xml', '0155a.xml', '0260f.xml', '0407b.xml', '0127d.xml', '3141b.xml', '0146d.xml', '0424a.xml', '6027d.xml', '3048a.xml', '0064c.xml', '0384c.xml', '0409a.xml', '3013c.xml', '0055d.xml', '0163a.xml', '0065a.xml', '0245a.xml', '6094b.xml', '0315e.xml', '0215e ...
# ('./top_folder', [], [])

# %% [markdown]
# Давайте напечатаем все возможные пути к папкам в текущей директории:

# %%
for root, dirs, files in os.walk('.'):
    print(root)
# Out:
# .
# ./.ipynb_checkpoints
# ./BAWE
# ./BAWE/documentation
# ./BAWE/CORPUS_ASCII
# ./BAWE/CORPUS_TXT
# ./BAWE/CORPUS_UTF-8
# ./top_folder

# %% [markdown]
# Видно, что в текущей папке есть папки `.ipynb_checkpoints`, `BAWE` и `top_folder`. В папке `BAWE` есть папки `documentation, CORPUS_ASCII, CORPUS_TXT и CORPUS_UTF-8`.
#
# Небольшое пояснение: BAWE расшифровывается как British Academic Written English, это корпус академических эссе, написанных в разных британских университетах.
#
# Теперь давайте напечатаем, сколько файлов (не папок!) лежит в каждой папке:

# %%
for root, dirs, files in os.walk('.'):
    print(root, len(files), sep='  ---  ')
# Out:
# .  ---  7
# ./.ipynb_checkpoints  ---  2
# ./BAWE  ---  0
# ./BAWE/documentation  ---  3
# ./BAWE/CORPUS_ASCII  ---  2762
# ./BAWE/CORPUS_TXT  ---  2761
# ./BAWE/CORPUS_UTF-8  ---  2762
# ./top_folder  ---  0

# %% [markdown]
# Ну и наконец, можно смотреть на разные файлы, лежащие в папках. Например, выяснять, есть ли файлы с именем длиной больше 10 (не учитывая расширение):

# %%
i = 0
names = []
for root, dirs, files in os.walk('.'):
    for f in files:
        if len(f.split('.')[0]) > 10:
            i += 1
            names.append(f.split('.')[0])
print('Найдено {} файла(ов):'.format(i))
for name in names:
    print(name)
# Out:
# Найдено 2 файла(ов):
# 1_Лекция_Лингвистические электронные ресурсы
# corpus_freq

# %% [markdown]
# Вот у меня в папке BAWE лежит корпус. Каждое эссе хранится в отдельном файле, а я хочу собрать информацию во всех из них. Эта задача решается с помощью os.walk(). Удобнее всего взять тексты, лежащие в каталоге CORPUS_TXT (потому что они в удобных текстовых файлах).

# %%
whole_corpus = ''
for root, dirs, files in os.walk('BAWE/CORPUS_TXT'):
    for f in files:
        if not f.endswith('.txt'):
            continue       # файлы с другими расширениями, не относящиеся к корпусу, нас не интересуют.
        with open(f, 'r', encoding='utf-8') as text:
            whole_corpus += text.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-1e626f75a56b> in <module>()
#       4         if not f.endswith('.txt'):
#       5             continue       # файлы с другими расширениями, не относящиеся к корпусу, нас не интересуют.
# ----> 6         with open(f, 'r', encoding='utf-8') as text:
#       7             whole_corpus += text.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: '0003h.txt'

# %% [markdown]
# Как же так - нет такого файла? В нужной папке он вроде есть:

# %%
'0003h.txt' in os.listdir('BAWE/CORPUS_TXT')
# Out:
# True

# %% [markdown]
# На самом деле, функция `open` очень зависит от указанного пути к файлу. В переменной `files` пути к файлам не лежат, только сами имена файлов, и когда мы передаем их функции open, она ищет такой файл в корневой папке, а там его, конечно, нет.
#
# Выход - берем путь к файлу из переменной `root`.

# %%
whole_corpus = ''
for root, dirs, files in os.walk('BAWE/CORPUS_TXT'):
    for f in files:
        if not f.endswith('.txt'):
            continue       # файлы с другими расширениями, не относящиеся к корпусу, нас не интересуют.
        with open(os.path.join(root, f), 'r', encoding='utf-8') as text:
            whole_corpus += text.read()

# %% [markdown]
# Теперь весь наш корпус записан в переменной `whole_corpus`. Можно грубо прикинуть, каков размер корпуса.

# %%
len(whole_corpus.split())
# Out:
# 6639776

# %% [markdown]
# С помощью os.walk() можно не только ходить по папкам сверху вниз, но и снизу вверх. Тогда программа начнет с самой глубокой папки в текущем дереве папок:

# %%
for root, dirs, files in os.walk('.', topdown=False):
    print(root)
# Out:
# ./.ipynb_checkpoints
# ./BAWE/documentation
# ./BAWE/CORPUS_ASCII
# ./BAWE/CORPUS_TXT
# ./BAWE/CORPUS_UTF-8
# ./BAWE
# ./top_folder
# .

# %% [markdown]
# Ну и наконец, можно ограничить папки, которые нужно посетить в ходе работы функции `os.walk()`. Поскольку на каждом шаге функция переходит в одну из папок, которые хранятся в переменной `dirs`, если мы удалим что-нибудь из этой переменной, то функция туда не перейдёт.
#
# Например, мы не хотим посещать скрытые папки (те, название которых начинается с точки):

# %%
for root, dirs, files in os.walk('.'):
    for d in dirs:
        if d.startswith('.'):
            dirs.remove(d)
    print(root)
# Out:
# .
# ./BAWE
# ./BAWE/documentation
# ./BAWE/CORPUS_ASCII
# ./BAWE/CORPUS_TXT
# ./BAWE/CORPUS_UTF-8
# ./top_folder

# %% [markdown]
# # Задания
#
# 1. Написать свою имплементацию функции shutil.rmtree() - то есть функцию, которая удаляет выбранную папку со всеми папками и файлами внутри неё.
# 2. Написать программу, которая рисует дерево текущей папки в таком виде:
#
#   --folder1
#         --folder4
#               file4
#               file5
#         --folder5
#   --folder2
#         file2
#         file3
#   --folder3
#
# 3. Скачать [архив](https://cloud.mail.ru/public/4bTt/XB9er2e3U) и распаковать его. Это уже знакомый нам корпус BAWE. В папке CORPUS_TXT и CORPUS_UTF-8 лежат одни и те же тексты, только в CORPUS_UTF-8 они с разметкой, а в CORPUS_TXT без разметки. Представленные тексты принадлежат к разным дисциплинам: History, Sociology, Literature, etc. Вам нужно собрать корпуса эссе для каждой дисциплины и посчитать частотный список для каждого корпуса. Для этого вам нужно извлечь категорию эссе из xml-файлов в папке CORPUS_UTF-8, а затем взять файл с таким же именем в папке CORPUS_TXT и добавить его содержимое в соответствующий корпус.
