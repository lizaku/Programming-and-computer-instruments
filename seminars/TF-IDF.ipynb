# %% [markdown]
# # Ключевые слова и tf-idf
#
# На прошлом занятии мы учились находить в тексте коллокации, сравнивая вероятности появления в тексте биграммы и слов, входящих в эту биграмму, по отдельности. Но если мы хотим оценить содержание текста, не читая его, и рассклассифицировать тексты по темам, одних коллокаций мало.
#
# О содержании текста много рассказывают ключевые слова. Что такое ключевое слово? Коллокации мы находили в одном-единственном тексте, а ключевые слова в одном отдельно взятом тексте не существуют. С точки зрения компьютерной лингвистики ключевые слова - это слова, которые часто встречаются в этом документе и редко во всех остальных. Если мы возьмём абстрактный текст про Францию, ключевыми словами будут сама _Франция_ и _Париж_, потому что они встретятся в этом тексте, а в текстах про другие страны или вообще не про страны _Франция_ и _Париж_ встречаются реже.
#
# Однако все-таки встречаются, правда? В тексте про знаменитые музеи мира, возможно, мы тоже встретим слова _Париж_ и _Франция_. когда речь зайдёт о Лувре, однако нельзя сказать, чтобы они были ключевыми. В чём разница между текстом про Францию и текстом про Лувр? Одно из различий - что в описании Лувра Париж будет упомянут только один раз, а в статье про Францию, возможно, и больше одного раза.
#
# __Тогда из чего складывается понятие "ключевое слово"?__
#
# * если слово появляется в документе часто, значит, оно важное и может быть ключевым.
# * если это же слово часто встречается и в других документах, значит, оно не такое же важное и ключевое.
#
# Ключевые слова должны быть частотными в конкретном документе и редкими во всех остальных. Для того, чтобы оценить степень важности слова в этом тексте, существует метрика, которая называется [__tf-idf (term frequency - inverted document frequency)__](https://en.wikipedia.org/wiki/Tf%E2%80%93idf).
#
# __term__ - это слово в тексте (более-менее)
# __document__ - это отдельный текстовый документ, будь то статья в Википедии, или новость, или анекдот.
#
# В метрике tf-idf учитываются те два компонента "ключевости" слова, о которых мы говорили раньше:
#
# * term frequency - насколько часто слово встречается в документе.
# * inverted document frequency - насколько редко слово встречается во всех остальных документах.
#
# Сама метрика представляет собой просто произведение этих двух частот.
#
# Как вы думаете, с какими текстами tf-idf работает хорошо, а с какими плохо? Будет ли tf-idf хорошо работать с очень короткими текстами (типа твитов)? А с очень длинными (типа романов Льва Толстого)?
#
# Давайте посчитаем tf-idf для слов в 100 статьях из русской Википедии.

# %%
def count_tf(word, text): # считаем, сколько раз слово встретилось в тексте и делим на общее количество слов (как в pmi)
    return text.count(word) / len(text)

# %%
def count_df(word, texts): # считаем, в скольких текстах встретилось слово
    n = [1 for text in texts if word in text]
    return sum(n)

# %%
# но нам нужна не прямая частота, а обратная
def count_idf(word, texts):
    n = len(texts) / (1 + count_df(word, texts)) # Зачем здесь единица?
    return n

# %%
# наконец считаем сам tf-idf. Как и во многих случаях, хорошая практика - брать не сами числа, а их логарифмы
from math import log
def count_tfidf(word, text, texts):
    tf = count_tf(word, text)
    idf = count_idf(word, texts)
    return log(tf, 10) * log(idf, 10)

# %% [markdown]
# Все, теперь мы можем обрабатывать тексты. Однако сначала их надо предобработать:

# %%
import re

punct = '[.,!«»?&@"$\[\]\(\):;%#&\'—-]'

def preprocessing(text): # функция предобработки текста
    text_wo_punct = re.sub(punct, '', text.lower()) # удаляем пунктуацию, приводим в нижний регистр
    words = text_wo_punct.strip().split() # делим по пробелам
    return words

# %%
import os

texts_dic = {}
for root, dirs, files in os.walk('wikipedia'):
    for f in files[:50]:
        with open(os.path.join(root, f), 'r', encoding='utf-8') as t:
            text = preprocessing(t.read())
            texts_dic[f.split('.')[0]] = text
texts = list(texts_dic.values())

# %%
for text in texts_dic:
    print("Top words in document {}".format(text)) # чтобы было понятно, какой документ мы обрабатывали
    scores = {} # здесь будем хранить оценки для каждого текста
    for word in texts_dic[text]:
        scores[word] =  count_tfidf(word, texts_dic[text], texts)
    sorted_words = sorted(scores.items(), key=lambda x: x[1])
    for word, score in sorted_words[:5]:
        print("\tWord: {}, TF-IDF: {}".format(word, round(score, 5)))
# Out:
# Top words in document Эскадренные миноносцы типов Z и Ca
# 	Word: mark, TF-IDF: -3.9876
# 	Word: пароперегревателями, TF-IDF: -3.9876
# 	Word: строились, TF-IDF: -3.9876
# 	Word: спаренный, TF-IDF: -3.9876
# 	Word: склонения, TF-IDF: -3.9876
# Top words in document Саботаж! (фильм, 2000)
# 	Word: плену, TF-IDF: -3.65694
# 	Word: рейтинг, TF-IDF: -3.65694
# 	Word: духа, TF-IDF: -3.65694
# 	Word: временами, TF-IDF: -3.65694
# 	Word: подлинного, TF-IDF: -3.65694
# Top words in document Никита (Латушко)
# 	Word: всеволожска, TF-IDF: -3.45677
# 	Word: всеволожске, TF-IDF: -3.45677
# 	Word: вывезено, TF-IDF: -3.45677
# 	Word: белорусская, TF-IDF: -3.45677
# 	Word: наместничество, TF-IDF: -3.45677
# Top words in document Поход уральцев из форта Александровского в Персию
# 	Word: карамышев, TF-IDF: -4.29225
# 	Word: константинополь, TF-IDF: -4.29225
# 	Word: архистратига, TF-IDF: -4.29225
# 	Word: месяца, TF-IDF: -4.29225
# 	Word: даль­ше, TF-IDF: -4.29225
# Top words in document Midori Days
# 	Word: тело, TF-IDF: -4.22344
# 	Word: такаги, TF-IDF: -4.22344
# 	Word: ангелы, TF-IDF: -4.22344
# 	Word: людьми, TF-IDF: -4.22344
# 	Word: подружка, TF-IDF: -4.22344
# Top words in document Алгоритм «кенгуру» Полларда
# 	Word: такое, TF-IDF: -4.11759
# 	Word: визуализации, TF-IDF: -4.11759
# 	Word: сталкиваются, TF-IDF: -4.11759
# 	Word: используемой, TF-IDF: -4.11759
# 	Word: подэкспоненциального, TF-IDF: -4.11759
# Top words in document Сабарка
# 	Word: учреждения, TF-IDF: -3.57692
# 	Word: продукции, TF-IDF: -3.57692
# 	Word: чувашское, TF-IDF: -3.57692
# 	Word: 1959, TF-IDF: -3.57692
# 	Word: сабарки, TF-IDF: -3.57692
# Top words in document Бондаренко, Александр Фёдорович
# 	Word: профессиональной, TF-IDF: -3.73801
# 	Word: вак, TF-IDF: -3.73801
# 	Word: докторских, TF-IDF: -3.73801
# 	Word: 3637, TF-IDF: -3.73801
# 	Word: сознание, TF-IDF: -3.73801
# Top words in document Каспаров, Геворг Владимирович
# 	Word: 4м, TF-IDF: -4.0248
# 	Word: шерифа, TF-IDF: -4.0248
# 	Word: безупречная, TF-IDF: -4.0248
# 	Word: исключена, TF-IDF: -4.0248
# 	Word: գևորգ, TF-IDF: -4.0248
# Top words in document Лозорайтис, Стасис
# 	Word: служил, TF-IDF: -3.54596
# 	Word: 1929, TF-IDF: -3.54596
# 	Word: креста, TF-IDF: -3.54596
# 	Word: канцелярии, TF-IDF: -3.54596
# 	Word: петлюры, TF-IDF: -3.54596
# Top words in document Числа Леонардо
# 	Word: oeis, TF-IDF: -3.29891
# 	Word: =1{\sqrt, TF-IDF: -3.29891
# 	Word: формулу, TF-IDF: -3.29891
# 	Word: =1+{\sqrt, TF-IDF: -3.29891
# 	Word: 753, TF-IDF: -3.29891
# Top words in document Макферсон (округ, Южная Дакота)
# 	Word: 811, TF-IDF: -3.54064
# 	Word: 028, TF-IDF: -3.54064
# 	Word: 9370, TF-IDF: -3.54064
# 	Word: 1873, TF-IDF: -3.54064
# 	Word: 9935, TF-IDF: -3.54064
# Top words in document 121-й мотострелковый полк
# 	Word: прорвавшихся, TF-IDF: -4.20465
# 	Word: послевоенные, TF-IDF: -4.20465
# 	Word: 1200, TF-IDF: -4.20465
# 	Word: лошадей, TF-IDF: -4.20465
# 	Word: дивизиона, TF-IDF: -4.20465
# Top words in document Всеволод Мстиславич (князь смоленский)
# 	Word: болен, TF-IDF: -3.4729
# 	Word: сошлись, TF-IDF: -3.4729
# 	Word: посаднику, TF-IDF: -3.4729
# 	Word: татар, TF-IDF: -3.4729
# 	Word: половину, TF-IDF: -3.4729
# Top words in document Крек, Михел
# 	Word: завершении, TF-IDF: -3.62526
# 	Word: ˈmiʃɛl, TF-IDF: -3.62526
# 	Word: последнее, TF-IDF: -3.62526
# 	Word: карьеру, TF-IDF: -3.62526
# 	Word: минуте, TF-IDF: -3.62526
# Top words in document Тирбах, Тассило
# 	Word: kermer, TF-IDF: -3.55991
# 	Word: стиль, TF-IDF: -3.55991
# 	Word: исполнив, TF-IDF: -3.55991
# 	Word: быстро, TF-IDF: -3.55991
# 	Word: automaten, TF-IDF: -3.55991
# Top words in document Усов, Дмитрий Васильевич
# 	Word: маркарьян, TF-IDF: -3.70225
# 	Word: инспектирование, TF-IDF: -3.70225
# 	Word: репрессии, TF-IDF: -3.70225
# 	Word: аоу, TF-IDF: -3.70225
# 	Word: расстрелян, TF-IDF: -3.70225
# Top words in document Стрельба в тель-авивском ЛГБТ-центре
# 	Word: hиp, TF-IDF: -4.01183
# 	Word: кровавый, TF-IDF: -4.01183
# 	Word: террористическая, TF-IDF: -4.01183
# 	Word: разглашения, TF-IDF: -4.01183
# 	Word: корин, TF-IDF: -4.01183
# Top words in document Околович, Иван Ильич
# 	Word: вф, TF-IDF: -3.78502
# 	Word: рогачёвского, TF-IDF: -3.78502
# 	Word: №2, TF-IDF: -3.78502
# 	Word: иркутск, TF-IDF: -3.78502
# 	Word: полным, TF-IDF: -3.78502
# Top words in document Мисс Вселенная 2010
# 	Word: поехать, TF-IDF: -3.93879
# 	Word: casino, TF-IDF: -3.93879
# 	Word: финальные, TF-IDF: -3.93879
# 	Word: 59й, TF-IDF: -3.93879
# 	Word: финалисток, TF-IDF: -3.93879
# Top words in document Ийон Тихий: Космопилот
# 	Word: удаётся, TF-IDF: -4.08724
# 	Word: biste, TF-IDF: -4.08724
# 	Word: фантастический, TF-IDF: -4.08724
# 	Word: астрономами, TF-IDF: -4.08724
# 	Word: столкновения, TF-IDF: -4.08724
# Top words in document Стромцов, Леонид Никифорович
# 	Word: современникмосква, TF-IDF: -3.65987
# 	Word: ювотінцев, TF-IDF: -3.65987
# 	Word: грифом, TF-IDF: -3.65987
# 	Word: знак, TF-IDF: -3.65987
# 	Word: 96ом, TF-IDF: -3.65987
# Top words in document Авраамий (Часовников)
# 	Word: протоиерей, TF-IDF: -3.84072
# 	Word: правом, TF-IDF: -3.84072
# 	Word: хутор, TF-IDF: -3.84072
# 	Word: черчение, TF-IDF: -3.84072
# 	Word: тщательные, TF-IDF: -3.84072
# Top words in document Jet Set Radio Future
# 	Word: групп, TF-IDF: -3.9036
# 	Word: vgaкабель, TF-IDF: -3.9036
# 	Word: scart, TF-IDF: -3.9036
# 	Word: оригинальных, TF-IDF: -3.9036
# 	Word: retro, TF-IDF: -3.9036
# Top words in document Памятник Стиву Джобсу (Одесса)
# 	Word: скульптор, TF-IDF: -3.40561
# 	Word: достигает, TF-IDF: -3.40561
# 	Word: неоновым, TF-IDF: -3.40561
# 	Word: ладони, TF-IDF: -3.40561
# 	Word: выбрана, TF-IDF: -3.40561
# Top words in document Транспорт в Ленинградской области
# 	Word: воздушный, TF-IDF: -3.88268
# 	Word: направлениям, TF-IDF: -3.88268
# 	Word: рощино, TF-IDF: -3.88268
# 	Word: сосновый, TF-IDF: -3.88268
# 	Word: гуп, TF-IDF: -3.88268
# Top words in document Линкольн (округ, Кентукки)
# 	Word: 038, TF-IDF: -3.55472
# 	Word: 2310, TF-IDF: -3.55472
# 	Word: пуласки, TF-IDF: -3.55472
# 	Word: 1780, TF-IDF: -3.55472
# 	Word: 361, TF-IDF: -3.55472
# Top words in document Куберская, Ирина Юрьевна
# 	Word: расскажи, TF-IDF: -3.4729
# 	Word: лауры, TF-IDF: -3.4729
# 	Word: энье, TF-IDF: -3.4729
# 	Word: спектаклей, TF-IDF: -3.4729
# 	Word: жуан, TF-IDF: -3.4729
# Top words in document Быков, Владислав Владимирович
# 	Word: свердловской, TF-IDF: -3.54596
# 	Word: сотрудничал, TF-IDF: -3.54596
# 	Word: заместителя, TF-IDF: -3.54596
# 	Word: мозгов, TF-IDF: -3.54596
# 	Word: 19941998, TF-IDF: -3.54596
# Top words in document NGC 3377
# 	Word: редакции, TF-IDF: -3.40561
# 	Word: aaron, TF-IDF: -3.40561
# 	Word: relations, TF-IDF: -3.40561
# 	Word: arxivastroph/9803087, TF-IDF: -3.40561
# 	Word: cho, TF-IDF: -3.40561
# Top words in document Пуя
# 	Word: сидоровская, TF-IDF: -3.63904
# 	Word: тулма, TF-IDF: -3.63904
# 	Word: 138, TF-IDF: -3.63904
# 	Word: 124, TF-IDF: -3.63904
# 	Word: водосбора, TF-IDF: -3.63904
# Top words in document Борисфен (футбольный клуб)
# 	Word: технические, TF-IDF: -3.56164
# 	Word: финансовой, TF-IDF: -3.56164
# 	Word: раскол, TF-IDF: -3.56164
# 	Word: создать, TF-IDF: -3.56164
# 	Word: первенстве, TF-IDF: -3.56164
# Top words in document Фабри де Пейреск, Никола-Клод
# 	Word: works, TF-IDF: -4.23716
# 	Word: покупателей, TF-IDF: -4.23716
# 	Word: наследница, TF-IDF: -4.23716
# 	Word: баньо, TF-IDF: -4.23716
# 	Word: заведение, TF-IDF: -4.23716
# Top words in document Storm Shadow
# 	Word: фрегаты, TF-IDF: -4.0256
# 	Word: земной, TF-IDF: -4.0256
# 	Word: пу, TF-IDF: -4.0256
# 	Word: приближаясь, TF-IDF: -4.0256
# 	Word: м=08, TF-IDF: -4.0256
# Top words in document Правление гетманского правительства
# 	Word: существовал, TF-IDF: -3.45266
# 	Word: царские, TF-IDF: -3.45266
# 	Word: іі, TF-IDF: -3.45266
# 	Word: петербурга, TF-IDF: -3.45266
# 	Word: обозный, TF-IDF: -3.45266
# Top words in document Ариэль, Борис Михайлович
# 	Word: цинзерлинг, TF-IDF: -3.47091
# 	Word: научной, TF-IDF: -3.47091
# 	Word: стопам, TF-IDF: -3.47091
# 	Word: моисей, TF-IDF: -3.47091
# 	Word: передовую, TF-IDF: -3.47091
# Top words in document Александрова-Игнатьева, Пелагея Павловна
# 	Word: 7е, TF-IDF: -4.15561
# 	Word: ленснабтехиздат, TF-IDF: -4.15561
# 	Word: аст, TF-IDF: -4.15561
# 	Word: иллюстрации, TF-IDF: -4.15561
# 	Word: преподавателем, TF-IDF: -4.15561
# Top words in document Собор Святой Варвары (Витебск)
# 	Word: небольшой, TF-IDF: -3.52257
# 	Word: белор, TF-IDF: -3.52257
# 	Word: кафедрального, TF-IDF: -3.52257
# 	Word: массивными, TF-IDF: -3.52257
# 	Word: станиславом, TF-IDF: -3.52257
# Top words in document Псарская резня
# 	Word: 700, TF-IDF: -4.91405
# 	Word: конкретному, TF-IDF: -4.91405
# 	Word: удерживают, TF-IDF: -4.91405
# 	Word: пишет, TF-IDF: -4.91405
# 	Word: вне, TF-IDF: -4.91405
# Top words in document Обратное поглощение
# 	Word: сделок, TF-IDF: -3.63752
# 	Word: рассматривать, TF-IDF: -3.63752
# 	Word: полученные, TF-IDF: -3.63752
# 	Word: вынесенные, TF-IDF: -3.63752
# 	Word: распускается, TF-IDF: -3.63752
# Top words in document Авиалинии Харькова
# 	Word: восстановлении, TF-IDF: -3.35218
# 	Word: регионах, TF-IDF: -3.35218
# 	Word: системс, TF-IDF: -3.35218
# 	Word: сертификата, TF-IDF: -3.35218
# 	Word: пассажироперевозок, TF-IDF: -3.35218
# Top words in document Авдеев, Александр Фёдорович (Герой Советского Союза)
# 	Word: шкадов, TF-IDF: -3.4729
# 	Word: авдеева, TF-IDF: -3.4729
# 	Word: любичев/, TF-IDF: -3.4729
# 	Word: госпитале, TF-IDF: -3.4729
# 	Word: люблинского, TF-IDF: -3.4729
# Top words in document Дагомейский разрыв
# 	Word: бенина, TF-IDF: -3.57356
# 	Word: европе, TF-IDF: -3.57356
# 	Word: влажные, TF-IDF: -3.57356
# 	Word: саванны, TF-IDF: -3.57356
# 	Word: востоку, TF-IDF: -3.57356
# Top words in document Handy Backup
# 	Word: jacobi, TF-IDF: -4.1379
# 	Word: vmware, TF-IDF: -4.1379
# 	Word: сетевое, TF-IDF: -4.1379
# 	Word: предоставляющих, TF-IDF: -4.1379
# 	Word: алгоритмами, TF-IDF: -4.1379
# Top words in document В Сиреневой Сторожке
# 	Word: экранизирован, TF-IDF: -3.59834
# 	Word: singular, TF-IDF: -3.59834
# 	Word: раскрытие, TF-IDF: -3.59834
# 	Word: либо, TF-IDF: -3.59834
# 	Word: скоттаэклса, TF-IDF: -3.59834
# Top words in document Скворцов, Лев Иванович
# 	Word: доцент, TF-IDF: -4.11414
# 	Word: высшее, TF-IDF: -4.11414
# 	Word: 19621991, TF-IDF: -4.11414
# 	Word: 262, TF-IDF: -4.11414
# 	Word: льва, TF-IDF: -4.11414
# Top words in document Эдуард Вестминстерский
# 	Word: любовник, TF-IDF: -3.7933
# 	Word: анне, TF-IDF: -3.7933
# 	Word: проявлялось, TF-IDF: -3.7933
# 	Word: бурный, TF-IDF: -3.7933
# 	Word: сторону, TF-IDF: -3.7933
# Top words in document Гопи
# 	Word: обстоятельно, TF-IDF: -3.82976
# 	Word: поклонение, TF-IDF: -3.82976
# 	Word: спутники, TF-IDF: -3.82976
# 	Word: индологической, TF-IDF: -3.82976
# 	Word: тунгавидья, TF-IDF: -3.82976
# Top words in document Такка Шантрье
# 	Word: юньнань, TF-IDF: -3.40561
# 	Word: семенами, TF-IDF: -3.40561
# 	Word: paxiana, TF-IDF: -3.40561
# 	Word: гуйчжоу, TF-IDF: -3.40561
# 	Word: cristata, TF-IDF: -3.40561
# Top words in document Генерал-лейтенант инженерно-технической службы
# 	Word: выполняемых, TF-IDF: -3.45266
# 	Word: 18111971, TF-IDF: -3.45266
# 	Word: топографических, TF-IDF: -3.45266
# 	Word: персональных, TF-IDF: -3.45266
# 	Word: 19401945, TF-IDF: -3.45266

# %% [markdown]
# # Задания
#
# 1. Попробуйте улучшить результат, очистив тексты от служебных и коротких слов.
# 2. Скомбинируйте PMI и tf-idf: сначала выделите коллокации при помощи PMI, а затем отберите наиболее значимые из этих коллокаций, вычислив их tf-idf score.
